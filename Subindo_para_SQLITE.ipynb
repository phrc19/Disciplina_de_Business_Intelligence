# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MICRODADOS.csv', sep=";", encoding='latin1')
df.head()
# Out:
# C:\Users\phrc_\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0      2023-04-02   2023-04-02      2023-03-31               NaN
# 1      2023-04-02   2023-04-02      2023-04-02               NaN
# 2      2023-04-02   2023-04-02      2023-03-30        2023-04-02
# 3      2023-04-02   2023-04-02      2023-03-31               NaN
# 4      2023-04-02   2023-04-02      2023-03-30               NaN
#
#   DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0            2023-04-02                 NaN                    NaN
# 1            2023-04-02                 NaN                    NaN
# 2            2023-04-02                 NaN                    NaN
# 3            2023-04-02                 NaN                    NaN
# ...

# %%
connection = sqlite3.connect('MICRODADOS.db')

df.to_sql('MICRODADOS', connection, if_exists='replace')
connection.close()
