# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MICRODADOS.csv', sep=";", encoding='latin1')
df.head()
# Out:
# C:\Users\PH\AppData\Local\Temp\ipykernel_16888\4166415650.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('MICRODADOS.csv', sep=";", encoding='latin1')
#   DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0      2023-03-06   2023-03-06      2023-03-04               NaN
# 1      2023-03-06   2023-03-06      2023-03-06               NaN
# 2      2023-03-06   2023-03-06      2023-03-01               NaN
# 3      2023-03-06   2023-02-23      2023-03-03               NaN
# 4      2023-03-06   2023-03-06      2023-03-04               NaN
#
#   DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0            2023-03-06                 NaN                    NaN
# 1            2023-03-06                 NaN                    NaN
# 2                   NaN                 NaN                    NaN
# 3            2023-03-06                 NaN                    NaN
# ...

# %%
df.columns
# Out:
# Index(['DataNotificacao', 'DataCadastro', 'DataDiagnostico',
#        'DataColeta_RT_PCR', 'DataColetaTesteRapido', 'DataColetaSorologia',
#        'DataColetaSorologiaIGG', 'DataEncerramento', 'DataObito',
#        'Classificacao', 'Evolucao', 'CriterioConfirmacao', 'StatusNotificacao',
#        'Municipio', 'Bairro', 'FaixaEtaria', 'IdadeNaDataNotificacao', 'Sexo',
#        'RacaCor', 'Escolaridade', 'Gestante', 'Febre',
#        'DificuldadeRespiratoria', 'Tosse', 'Coriza', 'DorGarganta', 'Diarreia',
#        'Cefaleia', 'ComorbidadePulmao', 'ComorbidadeCardio',
#        'ComorbidadeRenal', 'ComorbidadeDiabetes', 'ComorbidadeTabagismo',
#        'ComorbidadeObesidade', 'FicouInternado', 'ViagemBrasil',
#        'ViagemInternacional', 'ProfissionalSaude', 'PossuiDeficiencia',
#        'MoradorDeRua', 'ResultadoRT_PCR', 'ResultadoTesteRapido',
#        'ResultadoSorologia', 'ResultadoSorologia_IGG', 'TipoTesteRapido'],
#       dtype='object')

# %%
consultadf = df.query('Municipio=="CARIACICA" & ComorbidadeTabagismo=="Sim" & DataObito >= "2020" & Evolucao == "Óbito pelo COVID-19"')

# %%
consultadf[['Municipio' , 'ComorbidadeTabagismo' , 'DataObito', 'Evolucao' ]]
# Out:
#          Municipio ComorbidadeTabagismo   DataObito             Evolucao
# 90673    CARIACICA                  Sim  2023-01-10  Óbito pelo COVID-19
# 659736   CARIACICA                  Sim  2022-07-14  Óbito pelo COVID-19
# 771724   CARIACICA                  Sim  2022-07-15  Óbito pelo COVID-19
# 773119   CARIACICA                  Sim  2022-01-23  Óbito pelo COVID-19
# 933095   CARIACICA                  Sim  2022-06-29  Óbito pelo COVID-19
# ...            ...                  ...         ...                  ...
# 4699706  CARIACICA                  Sim  2020-06-19  Óbito pelo COVID-19
# 4700276  CARIACICA                  Sim  2020-05-08  Óbito pelo COVID-19
# 4705057  CARIACICA                  Sim  2020-05-10  Óbito pelo COVID-19
# 4705537  CARIACICA                  Sim  2020-05-05  Óbito pelo COVID-19
# 4715273  CARIACICA                  Sim  2020-04-21  Óbito pelo COVID-19
#
# [73 rows x 4 columns]
